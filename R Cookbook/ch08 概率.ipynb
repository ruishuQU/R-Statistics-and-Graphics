# %% [markdown]
# # 8 概率

# %% [markdown]
# R

# %% [markdown]
# | 函数名 | 目的             |
# | ------ | ---------------- |
# | dnorm  | 正态概率密度     |
# | pnorm  | 正态分布函数     |
# | qnorm  | 正态分位数函数   |
# | rnorm  | 正态分布的随机数 |
